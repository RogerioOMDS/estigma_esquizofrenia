# %%
import pandas as pd
import numpy as np
import urllib
import requests
from bs4 import BeautifulSoup
import os
from time import sleep
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError

# %%
df = pd.read_csv("links_estadao_rotulados.csv")
df.shape
# Out:
# (70, 3)

# %%
df.tail()
# Out:
#                                                  link  metaforico  \
# 65  https://saude.estadao.com.br/noticias/geral,ma...           0
# 66  https://saude.estadao.com.br/noticias/geral,a-...           0
# 67  https://saude.estadao.com.br/blogs/pilulas/ser...           0
# 68  https://saude.estadao.com.br/noticias/geral,ha...           0
# 69  https://saude.estadao.com.br/noticias/geral,fo...           0
#
#     indice_noticia
# 65              65
# 66              66
# 67              67
# 68              68
# 69              69

# %%
import spacy
nlp = spacy.load("pt_core_news_sm")

# %%
import random 
tempo = random.randint(1, 5)

# %%
import time

# %%
def limpa_paragrafos(link, tamanho):
    
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36"}
    try:
        req = Request(link, headers = headers)
        response = urlopen(req)
       
    except HTTPError as e: # erro de segurança do site, pode ser necessário usar user-Agent
        print(e.status, e.reason)

    except URLError as e:
        print(e.reason)
    
#     html = urllib.request.urlopen(link).read()
    html = response.read()
    soup = BeautifulSoup(html)

    for script in soup(["script", "style"]):
        script.decompose()

    lista = []
    for i in soup.stripped_strings:
        lista.append(i)
    
#     print(lista)

    miolo = []
    for i in lista:
        if len(i) > tamanho:
            miolo.append(i.replace('\r\n',''))
#             print(miolo)

    paragrafos = []
    for i in range(len(miolo)):
        if ('esquizo' in miolo[i]) or ('Esquizo' in miolo[i]):
            paragrafos.append(miolo[i])
    
    tempo = random.randint(1, 5)

    time.sleep(tempo)
    
#     for i in range(len(paragrafos)):
#         lista_final = []
#         doc = nlp(paragrafos[i].lower())
#         for token in doc:
#             valido = not token.is_stop and token.is_alpha
# #             valido = token.is_stop
#             if valido:
#                 lista_final.append(token.text)
    
#         limpo = ' '.join(lista_final)
#         paragrafos[i] = limpo
#         time.sleep(1)

    return paragrafos, miolo

# %%
link = df.link.values[3]
link
# Out:
# 'https://cultura.estadao.com.br/noticias/literatura,em-novo-livro-simon-schwartzman-articula-memorias-e-busca-novos-caminhos-para-o-brasil,70003644612'

# %%
paragrafos, miolo = limpa_paragrafos(link, 120)

# %%
str(paragrafos)
# Out:
# '[\'"Durante meus dois anos\\xa0em Berkeley, não\\xa0conheci um\\xa0americano sequer que pertencesse ao Partido Republicano.\\xa0Mas Ronald Reagan foi eleito governador da Califórnia em 1967,\\xa0e é dele a assinatura que tenho em meu diploma de doutorado,\\xa0como presidente do Conselho de Regentes da Universidade. Em\\xa01968, acompanhei pela televisão, horrorizado, as notícias sobre os\\xa0assassinatos de Martin Luther King e Robert Kennedy (...). No fim de 1968, estava tudo pronto para voltarmos ao Brasil,\\xa0onde eu deveria me integrar ao Departamento de Ciência Política\\xa0da UFMG e redigir minha tese. Foi quando o governo brasileiro\\xa0decretou o AI-5, interrompendo o que parecia ser um processo\\xa0de melhora do clima político no Brasil. A repressão recrudesceu\\xa0e fiquei sem saber o que fazer. Apter sugeriu que eu permanecesse por mais tempo em Berkeley, mas Carmen e eu acabamos\\xa0tomando uma decisão esquizofrênica: despachamos o contêiner\\xa0com nossa mudança para Buenos Aires e tomamos o avião para\\xa0o Brasil, a caminho de Belo Horizonte, com Michel, nosso filho\\xa0recém-nascido, no colo.”\']'

ada da parte mais dinâmica e autônoma da economia, baseada sobretudo em São Paulo. Daí o fato de uma das teses mais controvertidas e questionadas do livro ser a de que, no Brasil, o centro do poder econômico sempre teve uma posição relativamente subordinada, e por isso conflituosa, com o centro político.” Não é pouco mérito o fato de que, em\', \', a memória dos trabalhos acadêmicos e pesquisas realizadas e a lembrança de episódios pessoais sejam narradas com a mesma clareza e sabor. “Eu aprendi com o tempo que, se você não entende algo ao ler, a culpa é de quem escreveu. Há temas complexos, sem dúvida, e textos de caráter mais técnico, mas se você não tem c ...

# %%
df.link.iloc[1]
# Out:
# 'https://opiniao.estadao.com.br/noticias/artigos-dos-leitores,forum-dos-leitores,70003681598'

# %%
n_links = df.shape[0]
n_links
# Out:
# 70

# %%
for i in range(64,n_links):

    print(f"Processando {i} de {n_links}.")

    link = df.link.iloc[i]
    paragrafos, miolo = limpa_paragrafos(link, 70)
    df.loc[i, "paragrafos_resgatados"] = str(paragrafos)
    df.loc[i, "texto_completo"] = str(miolo)
# Out:
# Processando 64 de 70.
# Processando 65 de 70.
# Processando 66 de 70.
# Processando 67 de 70.
# Processando 68 de 70.
# Processando 69 de 70.

# %%
df
# Out:
#                                                  link  metaforico  \
# 0   https://opiniao.estadao.com.br/noticias/artigo...           1
# 1   https://opiniao.estadao.com.br/noticias/artigo...           1
# 2   https://opiniao.estadao.com.br/noticias/espaco...           1
# 3   https://cultura.estadao.com.br/noticias/litera...           1
# 4   https://cultura.estadao.com.br/noticias/geral,...           1
# ..                                                ...         ...
# 65  https://saude.estadao.com.br/noticias/geral,ma...           0
# 66  https://saude.estadao.com.br/noticias/geral,a-...           0
# 67  https://saude.estadao.com.br/blogs/pilulas/ser...           0
# 68  https://saude.estadao.com.br/noticias/geral,ha...           0
# 69  https://saude.estadao.com.br/noticias/geral,fo...           0
#
#     indice_noticia                              paragrafos_resgatados  \
# 0                0                                                 []
# 1                1                                                 []
# 2                2  ['A esquizofrenia se faz presente no governo: ...
# 3                3  ['"Durante meus dois anos\xa0em Berkeley, não\...
# 4                4  ['Considere uma fotografia. Nela, você vê meni...
# ..             ...                                                ...
# 65              65  ['Clarisse já fez oito visitas ao filho nos úl...
# 66              66  ['O canabidiol (CBD) é um dos 400 componentes ...
# 67              67  ['Filhos de homens que se tornaram pais aos 45...
# 68              68  ["Cem anos após ser citada pela primeira vez, ...
# 69              69  ['Os adolescentes que tinham uma força muscula...
#
#                                        texto_completo
# 0   ['Se as perspectivas para 2020 são de crescime...
# 1   ['Se as perspectivas para 2020 são de crescime...
# 2   ['Mais poder para quê? Para confrontos e mobil...
# 3   ['Em novo livro, Simon Schwartzman articula me...
# 4   ['Iniciamos a vacinação dentro de um campo pol...
# ..                                                ...
# 65  ['Clarisse Gularte ficou chocada com a execuçã...
# 66  ['Grupos brasileiros estão na vanguarda mundia...
# 67  ['Filhos de homens que se tornaram pais aos 45...
# 68  ['Para pesquisador, está comprovado que estres...
# 69  ['Força muscular pode estar ligada à longevida...
#
# [70 rows x 5 columns]

# %%
df_pronto = df.query("paragrafos_resgatados != '[]'")[df.paragrafos_resgatados.notnull()]
df_pronto
# Out:
# C:\Users\r-omd\AppData\Local\Temp\ipykernel_70520\3664636313.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df
# 56  https://ciencia.estadao.com.br/blogs/herton-es...           0
# 57  https://saude.estadao.com.br/noticias/geral,in...           0
# 58  https://saude.estadao.com.br/noticias/geral,ru...           0
# 60  https://ciencia.estadao.com.br/noticias/geral,...           0
# 61  https://ciencia.estadao.com.br/noticias/geral,...           0
# 62  https://saude.estadao.com.br/noticias/geral,sp...           0
# 64  https://saude.estadao.com.br/noticias/geral,es...           0
# 65  https://saude.estadao.com.br/noticias/geral,ma...           0
# 66  https://saude.estadao.com.br/noticias/geral,a-...           0
# 67  https://saude.estadao.com.br/blogs/pilulas/ser...           0
# 68  https://saude.estadao.com.br/noticias/geral,ha...           0
# 69  https://saude.estadao.com.br/noticias/geral,fo...           0
#
#     indice_noticia                              paragrafos_resgatados  \
# 2                2  ['A esquizofrenia se faz presente no governo: ...
# 3                3  ['"Durante meus dois anos\xa0em Berkeley, não\...
# 4                4  ['Considere uma fotografia. Nela, você vê meni...
# 5                5  [', mas você não o descartaria do universo dos...
# 6                6  ["Bom, acho que não dá pra responder essa perg...
# 8                8  ['"O contrato do Governo Federal com a Organiz...
# 9                9  ['Armani não está sozinho e sua voz tem ecoado...
# 11              11  ['Ao mostrar sua jovem esquerda isolada, criou...
# 13              13  ['já tinham nos revelado a pobreza da sua visã...
# 14              14  ['Quem vê estes bonecos à venda na loja do Met...
# 15              15  ['Sua personagem, Dra. Laura, ganhou espaço. J...
# 16              16  [', por exemplo, chegou a chamá-lo de “o médic...
# 17              17  ['A dura missão dos roteiristas, a de colocar ...
# 18              18  ['Adoro o mercado pois é um esquizofrênico pro...
# 20              20  ['Na política externa essa “dualidade de mando...
# 21              21  ['Vivemos, portanto, uma "esquizofrenia do pos...
# 22              22  ['Começando pela propaganda, a verdade é que o...
# 23              23  ['A esquizofrenia se faz presente no governo: ...
# 24              24  ['Muitos departamentos de marketing lançavam u...
# 25              25  ['Verdade que existe uma certa esquizofrenia n...
# 27              27  ['Não bastasse o desafio das urnas, acabamos c...
# 28              28  ['Para Frei David, coordenador executivo da ON...
# 29              29  ['"O discurso do Brasil lá fora é todo correto...
# 30              30  [', como o coronel Hugo Chávez na Venezuela, e...
# 31              31  ['Ciente de que o Brasil, assim como os brasil...
# 32              32  ['(PSL-SP), filho “zero três” do presidente, e...
# 33              33  ['(PDT), candidato derrotado à Presidência, e ...
# 34              34  ['a entrevista mais política, contundente e ef...
# 35              35  ['Roky foi diagnosticado com esquizofrenia ain...
# 36              36  ['que lhe mandava sobre a esquizofrenia e outr...
# 37              37  ['Embora tenha caído no esquecimento, o sumiço...
# 39              39  ['Surpreendentemente, até meados do século pas...
# 40              40  ['Lola (Valeria Pachner) é uma executiva bem s...
# 41              41  ['Após a pesquisa, o escritório médico do gove...
# 43              43  ['Aos 38 anos, a psiquiatra e neurocientista N...
# 44              44  ['Há vários estudos relativos ao tratamento da...
# 45              45  ['(1853-1890) e tantas foram as biografias do ...
# 46              46  [', doença neurodegenerativa e progressiva do ...
# 47              47  ['"Tem uma pesquisa famosa que diz que se você...
# 48              48  ['A vida que conhecemos de Antonio Callado foi...
# 49              49  ['Artigo publicado em março por pesquisadoras ...
# 50              50  ['"O Jeferson tinha esquizofrenia e não aderia...
# 51              51  ['. Num sentido estritamente médico, como fala...
# 52              52  ['O trabalho foi feito com base nas imagens ce...
# 53              53  ['A ABP quer levar isso à população. “A ABP qu...
# 54              54  ['A liberação do primeiro remédio aplica-se ao...
# 55              55  ['Os cientistas estavam interessados nos recep...
# 56              56  ['Depende de quem usa. Há dependentes graves d...
# 57              57  ['Com esquizofrenia e viciado em cocaína e mac...
# 58              58  ['No Hospital Thereza Perlatti, de Jaú, são co...
# 60              60  ['Brasileiros criam método para diagnosticar e...
# 61              61  ['Engenheiro formado pela Escola Politécnica d...
# 62              62  ['Outro privilégio é que ela pode dividir um q...
# 64              64  ['Os minicérebros foram desenvolvidos pela pes...
# 65              65  ['Clarisse já fez oito visitas ao filho nos úl...
# 66              66  ['O canabidiol (CBD) é um dos 400 componentes ...
# 67              67  ['Filhos de homens que se tornaram pais aos 45...
# 68              68  ["Cem anos após ser citada pela primeira vez, ...
# 69              69  ['Os adolescentes que tinham uma força muscula...
#
#                                        texto_completo
# 2   ['Mais poder para quê? Para confrontos e mobil...
# 3   ['Em novo livro, Simon Schwartzman articula me...
# 4   ['Iniciamos a vacinação dentro de um campo pol...
# 5   ['A produção mais recente de Billy Madison pod...
# 6   ["'Não idealizo nem romantizo maternidade', di...
# 8   ['Cargo anunciado para Regina Duarte não exist...
# 9   ['Estilista italiano fala sobre a crise de val...
# 11  ["'A Chinesa', clássico político do revolucion...
# 13  ['O chamado às armas de Kleber Mendonça Filho ...
# 14  ['Secretaria de Educação paulistana estuda bôn...
# 15  ["'O Brasil não se considera um país latino-am...
# 16  ['Com a morte do escritor, os militantes da pa...
# 17  ['Sexta e última temporada da produção não tev...
# 18  ['Novas possibilidades – Faria Lima Elevator –...
# 20  ['governa para e pela internet. Com resultado ...
# 21  ['Há alguns dias, me perguntaram se se posicio...
# 22  ['Hoje temos uma balbúrdia legislativa na área...
# 23  ['Mais poder para quê? Para confrontos e mobil...
# 24  ['A pandemia potencializou de forma avassalado...
# 25  ['O ambiente de M&A se aqueceu muito nos últim...
# 27  ['A legislação eleitoral não está totalmente a...
# 28  ['Levantamento foi feito com base nos inscrito...
# 29  ['Um recife de corais saudáveis na região de R...
# 30  ['Persio Arida alertou que o liberalismo de Bo...
# 31  ['Quando se pensa no lançamento de notas de va...
# 32  ['Em\xa0meio à crise no PSL, Centrão quer endu...
# 33  ["Bolsonaro exalta Olavo e diz esperar que rus...
# 34  ['Erros nas campanhas no 1.º turno e guerra de...
# 35  ['Banda foi pioneira no rock psicodélico e ser...
# 36  ["'Fênix Negra' fará com que o grupo de mutant...
# 37  ["Luca Guadagnino dirige novo 'Suspíria' com T...
# 39  ['Entrevista com André Negrão (HC-USP), Christ...
# 40  ['O Festival de Cinema de Berlim continua e Wi...
# 41  ['São verdadeiros exemplos de países com proto...
# 43  ['Neurocientista ressalta a importância de uma...
# 44  ['A confusão entre plantar maconha e produção ...
# 45  ['Livro mostra como a formação religiosa de Va...
# 46  ['Algoritmo computacional associado a eletroen...
# 47  ['Christian Dunker: milícias da alma e hiperme...
# 48  ['Documentário flagra o desalento do escritor ...
# 49  ['Pesquisas têm associado idade do homem a pro...
# 50  ['Bolsonaro sanciona lei que permite internaçã...
# 51  ["'Inteligência do psicopata é criação mística...
# 52  ['Circuitos cerebrais das emoções surgem antes...
# 53  ['Associação Psiquiátrica da América Latina (A...
# 54  ['Medicamento conta com um sensor que permite ...
# 55  ['Utilizando musgo, cientistas descobriram que...
# 56  ['Descriminalização não aumentaria consumo de ...
# 57  ['‘Internava ou ele morria’, conta mãe de paci...
# 58  ['Com medo de que pacientes fiquem na rua, fam...
# 60  ['Brasileiros criam método para diagnosticar e...
# 61  ['O engenheiro José Orsi teve a 1ª crise em 19...
# 62  ['SP encerra convênios e troca hospitais psiqu...
# 64  ['Modelos são utilizados para investigar desen...
# 65  ['Clarisse Gularte ficou chocada com a execuçã...
# 66  ['Grupos brasileiros estão na vanguarda mundia...
# 67  ['Filhos de homens que se tornaram pais aos 45...
# 68  ['Para pesquisador, está comprovado que estres...
# 69  ['Força muscular pode estar ligada à longevida...

# %%
df_pronto.to_csv("links_estadao_rotulados_resgatados.csv", index = False)

# %%
t = df.query("paragrafos_resgatados == '[]'")
t = df[((df.paragrafos_resgatados == '[]') | (df.paragrafos_resgatados.isnull()))]
t
# Out:
#                                                  link  metaforico  \
# 0   https://opiniao.estadao.com.br/noticias/artigo...           1
# 1   https://opiniao.estadao.com.br/noticias/artigo...           1
# 7   https://cultura.estadao.com.br/noticias/teatro...           1
# 10  https://cultura.estadao.com.br/noticias/geral,...           1
# 12  https://cultura.estadao.com.br/noticias/teatro...           1
# 19  https://eldorado.estadao.com.br/audios/program...           1
# 26  https://opiniao.estadao.com.br/noticias/artigo...           1
# 38  https://cultura.estadao.com.br/noticias/teatro...           0
# 42  https://internacional.estadao.com.br/noticias/...           0
# 59  https://ciencia.estadao.com.br/fotos/geral,gen...           0
# 63  https://saude.estadao.com.br/fotos/geral,fator...           0
#
#     indice_noticia paragrafos_resgatados  \
# 0                0                    []
# 1                1                    []
# 7                7                   NaN
# 10              10                    []
# 12              12                   NaN
# 19              19                   NaN
# 26              26                    []
# 38              38                   NaN
# 42              42                    []
# 59              59                   NaN
# 63              63                   NaN
#
#                                        texto_completo
# 0   ['Se as perspectivas para 2020 são de crescime...
# 1   ['Se as perspectivas para 2020 são de crescime...
# 7                                                 NaN
# 10  ['Com direção de Luiz Päetow, ex-integrante do...
# 12                                                NaN
# 19                                                NaN
# 26  ['Se as perspectivas para 2020 são de crescime...
# 38                                                NaN
# 42  ['O mal de Alzheimer pode ser previsto por mei...
# 59                                                NaN
# 63                                                NaN

# %%
t.link.values[1]
# Out:
# 'https://opiniao.estadao.com.br/noticias/artigos-dos-leitores,forum-dos-leitores,70003681598'

# %%
t.to_csv("links_estadao_rotulados_resgatados_sem_texto_descartar.csv", index = False)
